# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import glob
import os
import time
import feather
from sktime.classification.feature_based import RandomIntervalClassifier
from sktime.datasets import load_from_tsfile_to_dataframe
sns.set(style="whitegrid")

# %%
from RIC_transformers import *
# Out:
# WARNING:root:kats.utils.time_series_parameter_tuning requires ax-platform be installed
# WARNING:root:kats.models.metalearner.get_metadata requires ax-platform be installed

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ### LOAD DATA

# %%
# load training data
X_train, y_train = load_from_tsfile_to_dataframe('data/OliveOil_TRAIN.ts')

# load test data
X_test, y_test = load_from_tsfile_to_dataframe('data/OliveOil_TEST.ts')

# %%
#datasets = ['Adiac', 'Fish', 'OliveOil', 'SwedishLeaf']
datasets = [Fish', 'OliveOil', 'SwedishLeaf']


# --> reduce runtime, number of intervals < 31
nbrIntervals = [30, 24, 12, 27]

classifiers = ['RIC', 
               'RIC_catch22', 
               'RIC_kats',
               'RIC_tsfel',
               'RIC_tsfresh']

transformers = [None, Catch22(), Kats(), TSFel(), TSFresh()]
scores = np.zeros((len(transformers), len(datasets)))

# %% [markdown]
# --------------------------------------

# %%
def calcScore(X_train, y_train, X_test, y_test, nbrIntervals, transformer=None):
    
    classifier = RandomIntervalClassifier(n_intervals=nbrIntervals, interval_transformers=transformer, random_state=2)
    
    #start = time.time()
    classifier.fit(X_train, y_train)
    #end = time.time()

    #t0 = time.time()
    score = classifier.score(X_test, y_test)
    #t1 = time.time()

    #print('Fitting time: ', end-start)
    #print('Prediction time: ', t1-t0)
    
    return score

# %%
datasets = ['Adiac', 'Fish', 'OliveOil', 'SwedishLeaf']
for i in [0]:
    
    dataset   = datasets[i]
    intervals = nbrIntervals[i]
    print(dataset)
    
    # load training data
    X_train, y_train = load_from_tsfile_to_dataframe('data/' + dataset + '_TRAIN.ts')

    # load test data
    X_test, y_test = load_from_tsfile_to_dataframe('data/' + dataset + '_TEST.ts')
    
    j = 1
    transformer = transformers[j]
    scores[j,i] = calcScore(X_train, y_train, X_test, y_test, intervals, transformer)
# Out:
# Adiac

# %%
scores
# Out:
# array([[0.79028133, 0.94857143, 0.93333333, 0.9376    ],
#        [0.79283887, 0.89714286, 0.9       , 0.9312    ],
#        [0.        , 0.        , 0.86666667, 0.        ],
#        [0.        , 0.        , 0.9       , 0.        ],
#        [0.        , 0.        , 0.9       , 0.        ]])

# %% [markdown]
# --------------------------------------

# %%
datasets = ['Adiac', 'Fish', 'OliveOil', 'SwedishLeaf']
for i in range(2,4):
    
    dataset = datasets[i]
    print(dataset)
    
    # load training data
    X_train, y_train = load_from_tsfile_to_dataframe('data/' + dataset + '_TRAIN.ts')

    # load test data
    X_test, y_test = load_from_tsfile_to_dataframe('data/' + dataset + '_TEST.ts')
    
    j = 4
    scores[j,i] = calcScore(X_train, y_train, X_test, y_test, TSFresh())
# Out:
# OliveOil
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.05it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.70it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.98it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.97it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.29it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.20it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.87it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.62it/s]

# %%
scores = np.array([[0.77749361, 0.92571429, 0.93333333, 0.928     ],
       [0.76726343, 0.91428571, 0.9       , 0.912     ],
       [0.        , 0.        , 0.86666667, 0.        ],
       [0.78005115, 0.        , 0.9       , 0.        ],
       [0.        , 0.        , 0.9       , 0.        ]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 scores = array([[0.77749361, 0.92571429, 0.93333333, 0.928     ],
#       2        [0.76726343, 0.91428571, 0.9       , 0.912     ],
#       3        [0.        , 0.        , 0.86666667, 0.        ],
#       4        [0.78005115, 0.        , 0.9       , 0.        ],
#       5        [0.        , 0.        , 0.9       , 0.        ]])
#
# NameError: name 'array' is not defined

# %%
names = ['RIC', 'RIC_catch22', 'RIC_kats', 'RIC_tsfel', 'RIC_tsfresh']
scores = []

def calcScore(transformer=None, X_train, y_train, X_test, y_test):
    
    classifier = RandomIntervalClassifier(n_intervals=12, interval_transformers=transformer, random_state=2)
    
    start = time.time()
    classifier.fit(X_train, y_train)
    end = time.time()
    

    t0 = time.time()
    scores.append(classifier.score(X_test, y_test))
    t1 = time.time()

    #print('Fitting time: ', end-start)
    #print('Prediction time: ', t1-t0)

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ORIGINAL

# %%
calcScore()
# Out:
# Fitting time:  3.5162768363952637
# Prediction time:  0.8136663436889648

# %% [markdown]
# CATCH22

# %%
calcScore(transformer=Catch22())
# Out:
# Fitting time:  4.382179260253906
# Prediction time:  1.3176188468933105

# %% [markdown]
# KATS

# %%
calcScore(transformer=Kats())
# Out:
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# ERROR:root:Length of time series is shorter than nbins, unable to calculate flat spots feature
# ERROR:root:Length of time series is shorter than window_size, unable to calculate level shift features
# ERROR:root:Length is shorter than period, or constant time series, unable to calculate acf/pacf features
# WARNING:root:Holt Linear failed Cannot use heuristic method with less than 10 observations.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# WARNING:root:Holt-Winters failed Data must be positive.
# Fitting time:  25.53856611251831
# Prediction time:  19.54593253135681

# %% [markdown]
# TSFEL

# %%
calcScore(transformer=TSFel())
# Out:
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
# ...
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# *** Feature extraction finished ***
# Fitting time:  118.51034665107727
# Prediction time:  82.27201342582703

# %% [markdown]
# TSFRESH

# %%
calcScore(transformer=TSFresh())
# Out:
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.45it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.74it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.74it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.88it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.81it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.36it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.59it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.69it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.69it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.97it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.56it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.80it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.35it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.36it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.60it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.42it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.60it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.87it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.90it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.68it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.69it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.81it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.82it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.26it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.81it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.05it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.28it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.59it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.71it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.76it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.67it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.56it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.35it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.68it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.51it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.65it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.65it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.64it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.87it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.74it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.47it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.69it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.87it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.17it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.70it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.26it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.64it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.99it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.52it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.42it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.56it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.16it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.98it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.60it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.99it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.50it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.53it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.64it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.85it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.76it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.71it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.81it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.11it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.48it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.67it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.42it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.48it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.45it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.14it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.76it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.47it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.85it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.35it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.26it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.11it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.50it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.95it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.02it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.80it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.99it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.18it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.13it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.50it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.52it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.80it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.48it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.95it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.36it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.49it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.02it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.45it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.69it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.87it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.09it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.96it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.18it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.12it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.50it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.64it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.16it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.56it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.02it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.30it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.29it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.80it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.53it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.47it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.13it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.98it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.78it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.64it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.36it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.28it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.45it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.90it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.78it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.67it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.72it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.53it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.40it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.17it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.61it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.28it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.97it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.60it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.51it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.20it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.49it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.49it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.90it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.14it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.88it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.71it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.20it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.88it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.05it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.16it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.62it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.33it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.49it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.82it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.85it/s]
# ...
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.71it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.16it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.62it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.70it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.67it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.20it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.93it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.59it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.78it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.94it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.15it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.68it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.26it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.97it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.00it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.29it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.52it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.86it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.37it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.42it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.94it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.10it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.08it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.26it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.39it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.45it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.13it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.60it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.20it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.59it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.83it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.48it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.27it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.52it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.28it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.74it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.97it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.04it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.52it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.90it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.06it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.34it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.12it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.62it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.35it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.92it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.57it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.21it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.85it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.56it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.25it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.70it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.63it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.46it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.31it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.01it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.77it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.66it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.78it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.75it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.07it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.47it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.41it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.35it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.59it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.55it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.85it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.36it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.85it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.13it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.62it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.82it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.38it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.24it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.44it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.89it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.84it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.22it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.03it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.98it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.73it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.19it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.32it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.94it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.74it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.79it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.23it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.43it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.82it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.65it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.17it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.91it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.54it/s]
# Feature Extraction: 100%|█████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.41it/s]
# Fitting time:  228.11660289764404
# Prediction time:  154.19798946380615

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ### Plot

# %%
# row corresponds to classifier, col to dataset
accuracy = pd.DataFrame(scores, columns=datasets)
accuracy
# Out:
#       Adiac      Fish  OliveOil  SwedishLeaf
# 0  0.790281  0.948571  0.933333       0.9376
# 1  0.792839  0.897143  0.900000       0.9312
# 2  0.000000  0.000000  0.866667       0.0000
# 3  0.000000  0.000000  0.900000       0.0000
# 4  0.000000  0.000000  0.900000       0.0000

# %%
scores
# Out:
# [0.9333333333333333, 0.9, 0.8666666666666667, 0.9, 0.9]

# %%
def plotPerDataset(axes, y_pos, nbrPlots, df):
    
    for c in range(nbrPlots):
        
        axes[c].set_title(df.columns[c])
        axes[c].set_xlabel('Classifier')
        axes[c].set_ylabel('Accuracy')
        
        # Create bars
        axes[c].bar(y_pos, df.iloc[:, c], color='maroon')
        
        #
        axes[c].set_xticks(y_pos, classifiers, rotation='vertical')
    
    
def plotPerClassifier(axes, y_pos, nbrPlots, df):
    
    for c in range(nbrPlots):
        
        axes[c].set_title(classifiers[c])
        axes[c].set_xlabel('Dataset')
        axes[c].set_ylabel('Accuracy')
        
        # Create bars
        axes[c].bar(y_pos, df.iloc[c], color='maroon')
        
        #
        axes[c].set_xticks(y_pos, datasets, rotation='vertical') 
    

def plotAccuracy(df, perDataset = True):
    
    cols = 3
    
    if perDataset:
        nbrPlots = len(df.columns)
        y_pos    = np.arange(len(df))
    else:
        nbrPlots = len(df)
        y_pos    = np.arange(len(df.columns))
    
    rows = int(np.ceil(nbrPlots/cols))
    
    fig, ax = plt.subplots(rows, cols, figsize=(30, 30))
    # using padding
    fig.tight_layout(pad=14.0)
    
    axes = ax.flatten()
    
    if perDataset:
        plotPerDataset(axes, y_pos, nbrPlots, df)
    else:
        plotPerClassifier(axes, y_pos, nbrPlots, df)

# %%
plotAccuracy(accuracy)

# %%
plotAccuracy(accuracy, False)

# %%
def plotAccuracy(l1, l2, title):
    
    y_pos = np.arange(len(l1))
    
    # Create bars
    plt.bar(y_pos, l1, color='darkslategrey')
    
    # Create names on the x-axis
    plt.xticks(y_pos, l2,rotation='vertical')

    plt.xlabel('Method')
    plt.ylabel('Accuracy')
    plt.title(title)
    plt.show()
    
plotAccuracy(scores, names, 'RandomIntervalClassifier')
