# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import glob
import os
import feather
sns.set(style="whitegrid")

# %%
from basicFunction import getAccuracyValues
from basicFunction import plotError

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ### Preparing the frames to store information

# %%
from sklearn.ensemble import RandomForestRegressor

reg=RandomForestRegressor()

# %%
cod = getAccuracyValues(reg)
cod
# Out:
# Round 1
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
# Round  2
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  3
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  4
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  5
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  6
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#    GlobalClimate  HumidityHouse  HungaryChickenpox  IstanbulStockExchange  \
# 0       0.826533      -2.670058           0.354966              -0.192237
# 1       0.073110       0.253579           0.522590               0.196953
# 2       0.510349       0.703823           0.555804              -1.702177
# 3       0.131478       0.541614           0.332673              -0.735943
# 4       0.735957      -5.742595           0.454102              -0.515353
# 5       0.798975      -3.278286           0.158139              -0.201091
#
#    ParkingBirmingham  PedalMe
# 0           0.458867  0.73690
# 1          -2.044402 -6.25190
# 2           0.260074 -1.06130
# 3          -0.893587 -5.26475
# 4           0.513413 -0.46475
# 5           0.539889  0.16285

# %% [markdown]
# --------------------------------------

# %%
regressors = ['RFR_sklearn', 
              'RFR_catch22',
              'RFR_kats',
              'RFR_tsfeatures',
              'RFR_tsfel',
              'RFR_tsfresh']

# %%
plotError(cod, regressors, 'RandomForest x datasets already used for classification',perDataset = True)
