# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import glob
import os
import feather
sns.set(style="whitegrid")

# %%
from basicFunction import getAccuracyValues
from basicFunction import plotError

# %% [markdown]
# --------------------------------------

# %%
from sklearn.ensemble import ExtraTreesRegressor

reg = ExtraTreesRegressor()

# %%
cod = getAccuracyValues(reg)
cod
# Out:
# Round 1
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
# Round  2
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  3
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  4
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  5
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#
#
# Round  6
# GlobalClimate
# HumidityHouse
# HungaryChickenpox
# IstanbulStockExchange
# ParkingBirmingham
# PedalMe
#    GlobalClimate  HumidityHouse  HungaryChickenpox  IstanbulStockExchange  \
# 0       0.874598       0.034218           0.164490               0.093682
# 1      -0.008017      -4.164580           0.138445              -0.908616
# 2       0.659720      -1.321337           0.413997              -2.303614
# 3       0.206515      -0.149478           0.740194              -1.550360
# 4       0.728032      -3.334662           0.784117              -1.010599
# 5       0.823580      -5.201673           0.323423              -0.022263
#
#    ParkingBirmingham   PedalMe
# 0           0.423380   0.93385
# 1          -1.282028 -14.30435
# 2           0.474188  -0.23885
# 3          -1.221403 -10.73375
# 4           0.628447   0.59005
# 5           0.641452   0.58390

# %% [markdown]
# --------------------------------------

# %%
regressors = ['ETR_sklearn', 
              'ETR_catch22',
              'ETR_kats',
              'ETR_tsfeatures',
              'ETR_tsfel',
              'ETR_tsfresh']

# %%
plotError(cod, regressors, perDataset = True)
